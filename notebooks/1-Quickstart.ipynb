# %% [markdown]
# # GraphRAG Quickstart

# %% [markdown]
# ## Prerequisites
# Install 3rd party packages, not part of the Python Standard Library, to run the notebook

# %%
# ! pip install --upgrade pip
! pip install python-magic-bin
! pip install python-magic
! pip install devtools  
! pip install requests 
! pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-magic-bin in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.4.14)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: python-magic in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.4.27)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: devtools in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.12.2)
# Requirement already satisfied: asttokens<3.0.0,>=2.0.0 in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from devtools) (2.4.1)
# Requirement already satisfied: executing>=1.1.1 in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from devtools) (2.1.0)
# Requirement already satisfied: pygments>=2.15.0 in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from devtools) (2.18.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from asttokens<3.0.0,>=2.0.0->devtools) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2024.8.30)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tqdm in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.66.6)
# Requirement already satisfied: colorama in c:\users\dfang\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm) (0.4.6)

# %%
import getpass
import json
import time
from pathlib import Path

import magic
from tqdm import tqdm
import requests
from devtools import pprint

# %% [markdown]
# ## (REQUIRED) User Configuration
# Set the API subscription key, API base endpoint, and some file directory names that will be referenced later in the notebook.

# %% [markdown]
# #### API subscription key
#
# APIM supports multiple forms of authentication and access control (e.g. managed identity). For this notebook demonstration, we will use a **[subscription key](https://learn.microsoft.com/en-us/azure/api-management/api-management-subscriptions)**. To locate this key, visit the Azure Portal. The subscription key can be found under `<my_resource_group> --> <API Management service> --> <APIs> --> <Subscriptions> --> <Built-in all-access subscription> Primary Key`. For multiple API users, individual subscription keys can be generated.

# %%
ocp_apim_subscription_key = 'asdf'

"""
"Ocp-Apim-Subscription-Key": 
    This is a custom HTTP header used by Azure API Management service (APIM) to 
    authenticate API requests. The value for this key should be set to the subscription 
    key provided by the Azure APIM instance in your GraphRAG resource group.
"""
headers = {"Ocp-Apim-Subscription-Key": ocp_apim_subscription_key}

# %% [markdown]
# #### Setup directories and API endpoint
#
# For demonstration purposes, please use the provided `get-wiki-articles.py` script to download a small set of wikipedia articles or provide your own data (graphrag requires txt files to be utf-8 encoded).

# %%
"""
These parameters must be defined by the notebook user:

- file_directory: a local directory of text files. The file structure should be flat,
                  with no nested directories. (i.e. file_directory/file1.txt, file_directory/file2.txt, etc.)
- storage_name:   a unique name to identify a blob storage container in Azure where files
                  from `file_directory` will be uploaded.
- index_name:     a unique name to identify a single graphrag knowledge graph index.
                  Note: Multiple indexes may be created from the same `storage_name` blob storage container.
- endpoint:       the base/endpoint URL for the GraphRAG API (this is the Gateway URL found in the APIM resource).
"""

file_directory = "test1"
storage_name = "graphrag"
index_name = "test1"
endpoint = "http://localhost/"

# %%
assert (
    file_directory != "" and storage_name != "" and index_name != "" and endpoint != ""
)

# %% [markdown]
# ## Upload Files
#
# For a demonstration of how to index data in graphrag, we first need to ingest a few files into graphrag.

# %%
def upload_files(
    file_directory: str,
    storage_name: str,
    batch_size: int = 100,
    overwrite: bool = True,
    max_retries: int = 5,
) -> requests.Response | list[Path]:
    """
    Upload files to a blob storage container.

    Args:
    file_directory - a local directory of .txt files to upload. All files must have utf-8 encoding.
    storage_name - a unique name for the Azure storage blob container.
    batch_size - the number of files to upload in a single batch.
    overwrite - whether or not to overwrite files if they already exist in the storage blob container.
    max_retries - the maximum number of times to retry uploading a batch of files if the API is busy.

    NOTE: Uploading files may sometimes fail if the blob container was recently deleted
    (i.e. a few seconds before. The solution "in practice" is to sleep a few seconds and try again.
    """
    url = endpoint + "/data"

    def upload_batch(
        files: list, storage_name: str, overwrite: bool, max_retries: int
    ) -> requests.Response:
        for _ in range(max_retries):
            response = requests.post(
                url=url,
                files=files,
                params={"storage_name": storage_name, "overwrite": overwrite},
                headers=headers,
            )
            # API may be busy, retry
            if response.status_code == 500:
                print("API busy. Sleeping and will try again.")
                time.sleep(10)
                continue
            return response
        return response

    batch_files = []
    accepted_file_types = ["text/plain"]
    filepaths = list(Path(file_directory).iterdir())
    for file in tqdm(filepaths):
        # validate that file is a file, has acceptable file type, has a .txt extension, and has utf-8 encoding
        if (
            not file.is_file()
            or file.suffix != ".txt"
            or magic.from_file(str(file), mime=True) not in accepted_file_types
        ):
            print(f"Skipping invalid file: {file}")
            continue
        # open and decode file as utf-8, ignore bad characters
        batch_files.append(
            ("files", open(file=file, mode="r", encoding="utf-8", errors="ignore"))
        )
        # upload batch of files
        if len(batch_files) == batch_size:
            response = upload_batch(batch_files, storage_name, overwrite, max_retries)
            # if response is not ok, return early
            if not response.ok:
                return response
            batch_files.clear()
    # upload remaining files
    if len(batch_files) > 0:
        response = upload_batch(batch_files, storage_name, overwrite, max_retries)
    return response


response = upload_files(
    file_directory=file_directory,
    storage_name=storage_name,
    batch_size=100,
    overwrite=True,
)
if not response.ok:
    print(response.text)
else:
    print(response)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 92.52it/s]
# <Response [200]>

# %% [markdown]
# ## Build an Index
#
# After data files have been uploaded, we can construct a knowledge graph by building a search index.

# %%
def build_index(
    storage_name: str,
    index_name: str,
) -> requests.Response:
    """Create a search index.
    This function kicks off a job that builds a knowledge graph index from files located in a blob storage container.
    """
    url = endpoint + "/index"
    request = {"storage_name": storage_name, "index_name": index_name}
    return requests.post(url, params=request, headers=headers)


response = build_index(storage_name=storage_name, index_name=index_name)
print(response)
if response.ok:
    print(response.text)
else:
    print(f"Failed to submit job.\nStatus: {response.text}")
# Out:
# <Response [200]>
# {"status":"Indexing job scheduled"}

# %% [markdown]
# ### Check status of an indexing job
#
# Please wait for your index to reach 100 percent completion before continuing on to the next section (running queries). You may rerun the next cell multiple times to monitor status. Note: the indexing speed of graphrag is directly correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
def index_status(index_name: str) -> requests.Response:
    url = endpoint + f"/index/status/{index_name}"
    return requests.get(url, headers=headers)


response = index_status(index_name)
pprint(response.json())
# Out:
# {
#     'status_code': 200,
#     'index_name': 'test1',
#     'storage_name': 'graphrag',
#     'status': 'complete',
#     'percent_complete': 100.0,
#     'progress': '16 out of 16 workflows completed successfully.',
# }

# %% [markdown]
# ## Query
#
# Once an indexing job is complete, the knowledge graph is ready to query. Two types of queries (global and local) are currently supported. We encourage you to try both and experience the difference in responses. Note that query response time is also correlated to the TPM quota of the Azure OpenAI model you are using.

# %%
# a helper function to parse out the result from a query response
def parse_query_response(
    response: requests.Response, return_context_data: bool = False
) -> requests.Response | dict[list[dict]]:
    """
    Print response['result'] value and return context data.
    """
    if response.ok:
        print(json.loads(response.text)["result"])
        if return_context_data:
            return json.loads(response.text)["context_data"]
        return response
    else:
        print(response.reason)
        print(response.content)
        return response

# %% [markdown]
# ### Global Query
#
# Global queries are resource-intensive, but provide good responses to questions that require an understanding of the dataset as a whole.

# %%
# %%time


def global_search(
    index_name: str | list[str], query: str, community_level: int
) -> requests.Response:
    """Run a global query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/global"
    # optional parameter: community level to query the graph at (default for global query = 1)
    request = {
        "index_name": index_name,
        "query": query,
        "community_level": community_level,
    }
    return requests.post(url, json=request, headers=headers)


# perform a global query
global_response = global_search(
    index_name=index_name,
    query="Summarize the main topics found in this data",
    community_level=1,
)
global_response_data = parse_query_response(global_response, return_context_data=True)
global_response_data
# Out:
# # Summary of Main Topics in the Data
#
# ## Bangladesh Liberation War and Military Forces
#
# The Bangladesh Liberation War was a pivotal event in the history of Bangladesh, marked by the significant contributions of the Bangladesh Forces. These forces were composed of guerrilla fighters and military personnel who defected from the Pakistan Army, Navy, and Air Force. Their efforts were crucial in the fight for Bangladesh's independence, engaging in various military operations against the Pakistan Army [Data: Reports (1)].
#
# ## Formation of the Bangladesh Air Force and Navy
#
# The Bangladesh Air Force was officially formed on 28 September 1971, with personnel of Bengali origin from the Pakistan Air Force. This formation was a significant enhancement to the military capabilities of the Bangladesh Forces during the liberation efforts [Data: Reports (1)]. Similarly, the Bangladesh Navy was established by Bengali sailors and officers who defected from the Pakistan Navy. It played a crucial role in naval operations, particularly at the ports of Chittagong and Mongla, making these locations highly lethal for occupation forces [Data: Reports (2)].
#
# ## Key Brigades: Z Force, K Force, and S Force
#
# Several key brigades were instrumental during the Bangladesh Liberation War. Z Force, commanded by Lieutenant Colonel Ziaur Rahman, was formed with battalions from the East Bengal Regiment and played a crucial role in the war [Data: Reports (3)]. K Force, commanded by Lieutenant Colonel Khaled Mosharraf, was another critical brigade formed in Agartala with battalions from the East Bengal Regiment [Data: Reports (0)]. S Force, commanded by Major K M Shafiullah, also played a significant role, composed of battalions from the East Bengal Regiment [Data: Reports (4)].
#
# ## Strategic Operations and Memorials
#
# Strategic operations conducted in Indian Territory were crucial for the Bangladesh Forces, providing logistical support and enhancing military planning [Data: Reports (1)]. Additionally, Shikha Anirban, meaning Eternal Flame, is a memorial located at Dhaka Cantonment. It serves as a site for laying floral wreaths to honor the sacrifices made during the Bangladesh Liberation War [Data: Reports (1)].
#
# These topics collectively highlight the strategic, operational, and commemorative aspects of the Bangladesh Liberation War, underscoring the contributions of various military forces and the enduring legacy of their efforts.
# CPU times: total: 0 ns
# Wall time: 31.2 s
# {'reports': [{'id': '1',
#    'title': 'Bangladesh Forces and Liberation War',
#    'occurrence weight': 1.0,
#    'content': "# Bangladesh Forces and Liberation War\n\nThe community is centered around the Bangladesh Forces, which played a pivotal role in the Bangladesh Liberation War. Key entities include the Bangladesh Air Force, Bangladesh Navy, and various brigades such as Z Force, K Force, and S Force. The community's activities were supported by operations in Indian Territory and memorialized at Shikha Anirban.\n\n## Role of Bangladesh Forces in the Liberation War\n\nThe Bangladesh Forces were a crucial component in the Bangladesh Liberation War, consisting of guerrilla fighters and military personnel who defected from the Pakistan Army, Navy, and Air Force. These forces were instrumental in the fight for Bangladesh's independence, engaging in various military operations against the Pakistan Army [Data: Entities (2); Relationships (0)].\n\n## Formation and significance of the Bangladesh Air Force\n\nThe Bangladesh Air Force was officially formed on 28 September 1971, with personnel of Bengali origin from the Pakistan Air Force. This formation was a significant development in the military capabilities of the Bangladesh Forces, providing air support during the liberation efforts. The Air Force began its operations from an airfield in Dimapur, highlighting its strategic importance [Data: Entities (7); Claims (5); Relationships (7, 20)].\n\n## Strategic operations in Indian Territory\n\nThe Bangladesh Forces organized regular units across the border in Indian Territory, which played a strategic role in their operations during the war. This cross-border collaboration was crucial for logistical support and military planning, enhancing the effectiveness of the Bangladesh Forces [Data: Entities (15); Relationships (8)].\n\n## Commemoration at Shikha Anirban\n\nShikha Anirban, meaning Eternal Flame, is a memorial located at Dhaka Cantonment. It serves as a site for laying floral wreaths to honor the sacrifices made during the Bangladesh Liberation War. This memorial symbolizes the enduring legacy and remembrance of the struggle for independence [Data: Entities (14); Relationships (1)].\n\n## Formation of the Bangladesh Navy\n\nThe Bangladesh Navy was formed as part of the Bangladesh Forces, contributing to the maritime defense and operations during the liberation war. This formation was a critical step in establishing a comprehensive military structure for the newly emerging nation [Data: Relationships (6)].",
#    'rank': 9.0,
#    'index_name': 'test1',
#    'index_id': '1'},
#   {'id': '4',
#    'title': 'S Force and Bangladesh Liberation War',
#    'occurrence weight': 1.0,
#    'content': "# S Force and Bangladesh Liberation War\n\nThe community is centered around S Force, a brigade of the Bangladesh Forces, which played a significant role during the Bangladesh Liberation War. Key entities include Major K M Shafiullah, the commander of S Force, and Hezamara, the location where S Force was formed. The brigade was composed of battalions from the East Bengal Regiment, highlighting its strategic importance in the war effort.\n\n## S Force as a pivotal military unit\n\nS Force was a brigade within the Bangladesh Forces, underscoring its importance in the military operations during the Bangladesh Liberation War. The formation of S Force with battalions from the East Bengal Regiment indicates its strategic role in the conflict. This brigade's operations and contributions were vital in the context of the war, making it a key entity in the historical narrative of Bangladesh's fight for independence [Data: Entities (5); Relationships (5, 16)].\n\n## Major K M Shafiullah's leadership\n\nMajor K M Shafiullah served as the commander of S Force, highlighting his leadership role during the Bangladesh Liberation War. His command was crucial in directing the operations of S Force, which was a significant component of the Bangladesh Forces. The leadership of Major Shafiullah is a noteworthy aspect of the community, reflecting the human element behind the military strategies and actions taken during the war [Data: Entities (10); Relationships (15)].\n\n## Formation of S Force at Hezamara\n\nHezamara is identified as the location where S Force was formed, marking it as a significant geographical point in the history of the Bangladesh Liberation War. The formation of such a pivotal brigade at this location underscores its strategic importance. Understanding the role of Hezamara provides insights into the logistical and strategic planning that went into the war efforts [Data: Entities (18); Relationships (17)].\n\n## Integration of East Bengal Regiment battalions\n\nS Force was formed with battalions from the East Bengal Regiment, indicating a strategic integration of existing military resources to bolster the Bangladesh Forces. This integration reflects the tactical decisions made to enhance the effectiveness of the military operations during the liberation war. The East Bengal Regiment's involvement is a testament to the collaborative efforts within the Bangladesh Forces [Data: Relationships (16)].",
#    'rank': 8.5,
#    'index_name': 'test1',
#    'index_id': '4'},
#   {'id': '2',
#    'title': 'Bangladesh Navy and Port Operations',
#    'occurrence weight': 1.0,
#    'content': "# Bangladesh Navy and Port Operations\n\nThe community is centered around the Bangladesh Navy, which was formed by Bengali sailors and officers who left the Pakistan Navy. The Navy played a crucial role in naval operations at the ports of Chittagong and Mongla, making these locations highly lethal for occupation forces. The Bangladesh Navy was part of the larger Bangladesh Forces.\n\n## Formation of the Bangladesh Navy\n\nThe Bangladesh Navy was formed by Bengali sailors and officers who defected from the Pakistan Navy. This initial group included two ships, BNS Padma and PALASH, and 45 personnel. The formation of the Navy was a pivotal moment in the liberation efforts, providing a naval force that could challenge the occupation forces. [Data: Entities (6); Claims (4)]\n\n## Strategic operations in Chittagong\n\nThe Bangladesh Navy conducted significant operations in the port city of Chittagong. These operations were highly effective, making the port a lethal zone for the occupation forces. The strategic importance of Chittagong as a port city amplified the impact of these naval operations. [Data: Entities (11); Relationships (18)]\n\n## Impactful operations in Mongla\n\nSimilar to Chittagong, the Bangladesh Navy also carried out operations in Mongla, another critical port city. These operations contributed to the overall effectiveness of the naval campaign against the occupation forces, further demonstrating the Navy's strategic capabilities. [Data: Entities (12); Relationships (19)]\n\n## Integration with Bangladesh Forces\n\nThe Bangladesh Navy was an integral part of the Bangladesh Forces, which were crucial in the liberation efforts. This integration highlights the coordinated approach taken by the liberation forces to maximize their impact against the occupation. [Data: Relationships (6)]\n\n## Naval operations' role in liberation\n\nThe naval operations conducted by the Bangladesh Navy were a key component of the broader liberation strategy. By targeting critical port cities, the Navy was able to disrupt supply lines and weaken the occupation forces' hold on the region. This strategic approach was instrumental in the success of the liberation efforts. [Data: Claims (4)]",
#    'rank': 8.5,
#    'index_name': 'test1',
#    'index_id': '2'},
#   {'id': '0',
#    'title': 'K Force and Bangladesh Liberation War',
#    'occurrence weight': 1.0,
#    'content': "# K Force and Bangladesh Liberation War\n\nThe community centers around K Force, a brigade of the Bangladesh Forces, commanded by Lieutenant Colonel Khaled Mosharraf. K Force was formed with battalions from the East Bengal Regiment and was established in Agartala during the Bangladesh Liberation War.\n\n## K Force as a key military unit\n\nK Force was a crucial brigade within the Bangladesh Forces, playing a significant role during the Bangladesh Liberation War. It was formed with battalions from the East Bengal Regiment, highlighting its strategic importance in the military operations of the time. The formation of K Force marked a pivotal moment in the war, contributing to the overall efforts for Bangladesh's independence. [Data: Entities (4); Relationships (4, 13)]\n\n## Leadership of Lieutenant Colonel Khaled Mosharraf\n\nLieutenant Colonel Khaled Mosharraf was the commander of K Force, providing leadership and strategic direction during the Bangladesh Liberation War. His role was instrumental in organizing and leading the brigade, which was a key component of the Bangladesh Forces. Khaled Mosharraf's leadership is a significant aspect of the community, reflecting the importance of effective military command in the success of liberation efforts. [Data: Entities (9); Relationships (12)]\n\n## Formation of K Force in Agartala\n\nK Force was formed in Agartala, a location that played a strategic role during the Bangladesh Liberation War. The choice of Agartala as the formation site underscores its logistical and strategic significance in the context of the war. This location served as a base for organizing and launching military operations, contributing to the broader objectives of the Bangladesh Forces. [Data: Entities (17); Relationships (14)]\n\n## Integration with the East Bengal Regiment\n\nK Force was formed with battalions from the East Bengal Regiment, indicating a strong integration with existing military structures. This integration was crucial for leveraging the experience and capabilities of the East Bengal Regiment, enhancing the operational effectiveness of K Force. The collaboration between these military units was a key factor in the success of their operations during the war. [Data: Relationships (13)]",
#    'rank': 8.5,
#    'index_name': 'test1',
#    'index_id': '0'},
#   {'id': '3',
#    'title': 'Z Force and East Bengal Regiment',
#    'occurrence weight': 1.0,
#    'content': "# Z Force and East Bengal Regiment\n\nThe community is centered around Z Force, a brigade of the Bangladesh Forces commanded by Lieutenant Colonel Ziaur Rahman, and its formation with battalions from the East Bengal Regiment during the Bangladesh Liberation War. The entities are interconnected through their military roles and geographical significance, particularly in relation to Mymensingh.\n\n## Z Force as a key military brigade\n\nZ Force was a pivotal brigade within the Bangladesh Forces, playing a crucial role during the Bangladesh Liberation War. It was commanded by Lieutenant Colonel Ziaur Rahman, highlighting its strategic importance in the military operations of the time. The formation of Z Force with battalions from the East Bengal Regiment underscores its foundational military strength and its role in the liberation efforts [Data: Entities (3); Relationships (3, 10)].\n\n## Role of the East Bengal Regiment\n\nThe East Bengal Regiment was instrumental in the formation of multiple forces, including Z Force, K Force, and S Force, during the Bangladesh Liberation War. This regiment provided the necessary battalions that formed the core of these forces, indicating its significant contribution to the military efforts. The regiment's involvement with multiple forces highlights its extensive role in the liberation movement [Data: Entities (16); Relationships (10, 13, 16)].\n\n## Leadership of Lieutenant Colonel Ziaur Rahman\n\nLieutenant Colonel Ziaur Rahman was the commander of Z Force, a position that placed him at the forefront of the military strategy during the Bangladesh Liberation War. His leadership was crucial in directing the operations of Z Force, which was a key component of the Bangladesh Forces. Ziaur Rahman's role as a commander underscores the importance of leadership in military success [Data: Entities (8); Relationships (9)].\n\n## Geographical significance of Mymensingh\n\nMymensingh holds geographical significance as the location opposite to which Z Force was raised. This strategic positioning was likely chosen for its tactical advantages during the Bangladesh Liberation War. The proximity of Z Force to Mymensingh highlights the importance of geographical considerations in military planning and operations [Data: Entities (19); Relationships (11)].\n\n## Interconnectedness of military forces\n\nThe interconnectedness of Z Force with other military units such as K Force and S Force, all formed with battalions from the East Bengal Regiment, illustrates a coordinated military strategy during the Bangladesh Liberation War. This network of forces demonstrates the collaborative efforts required to achieve military objectives and the shared resources among different units [Data: Relationships (10, 13, 16)].",
#    'rank': 8.0,
#    'index_name': 'test1',
#    'index_id': '3'}],
#  'entities': [],
#  'relationships': [],
#  'claims': [],
#  'sources': []}

# %% [markdown]
# ### Local Query
#
# Local search queries are best suited for narrow-focused questions that require an understanding of specific entities mentioned in the documents (e.g. What are the healing properties of chamomile?)

# %%
# %%time


def local_search(
    index_name: str | list[str], query: str, community_level: int
) -> requests.Response:
    """Run a local query over the knowledge graph(s) associated with one or more indexes"""
    url = endpoint + "/query/local"
    # optional parameter: community level to query the graph at (default for local query = 2)
    request = {
        "index_name": index_name,
        "query": query,
        "community_level": community_level,
    }
    return requests.post(url, json=request, headers=headers)


# perform a local query
local_response = local_search(
    index_name=index_name,
    query="Summarize the main topics found in this data",
    community_level=2,
)
local_response_data = parse_query_response(local_response, return_context_data=True)
local_response_data
# Out:
# # Overview of Main Topics
#
# The data provided focuses on the Bangladesh Liberation War, highlighting the pivotal role played by the Bangladesh Forces, which included the Bangladesh Air Force, Bangladesh Navy, and various brigades such as Z Force, K Force, and S Force. These forces were instrumental in the fight for Bangladesh's independence from Pakistan, engaging in significant military operations and strategic collaborations.
#
# ## Bangladesh Forces and Their Role
#
# The Bangladesh Forces were a crucial component in the Bangladesh Liberation War, consisting of guerrilla fighters and military personnel who defected from the Pakistan Army, Navy, and Air Force. These forces organized regular units across the border in Indian Territory, which played a strategic role in their operations during the war [Data: Bangladesh Forces and Liberation War (1); Entities (2, 15); Relationships (0, 8)].
#
# ## Formation of Military Units
#
# The formation of the Bangladesh Air Force and Navy marked significant developments in the military capabilities of the Bangladesh Forces. The Bangladesh Air Force was officially formed on 28 September 1971, with personnel of Bengali origin from the Pakistan Air Force, and began operations from an airfield in Dimapur [Data: Bangladesh Forces and Liberation War (1); Entities (7, 13); Relationships (7, 20)]. The Bangladesh Navy was formed by Bengali sailors and officers who left the Pakistan Navy, contributing to maritime defense during the liberation war [Data: Bangladesh Forces and Liberation War (1); Entities (6); Relationships (6)].
#
# ## Brigades and Leadership
#
# The data highlights the formation and significance of various brigades within the Bangladesh Forces. S Force, commanded by Major K M Shafiullah, was formed with battalions from the East Bengal Regiment at Hezamara, playing a strategic role in the conflict [Data: S Force and Bangladesh Liberation War (4); Entities (5, 10, 16, 18); Relationships (5, 15, 16, 17)]. Similarly, Z Force and K Force were formed with battalions from the East Bengal Regiment, commanded by Lieutenant Colonels Ziaur Rahman and Khaled Mosharraf, respectively [Data: Bangladesh Forces and Liberation War (1); Entities (3, 4, 8, 9, 16); Relationships (3, 4, 9, 12, 13)].
#
# ## Commemoration and Legacy
#
# The enduring legacy of the Bangladesh Liberation War is commemorated at Shikha Anirban, a memorial located at Dhaka Cantonment. This site serves as a place for laying floral wreaths to honor the sacrifices made during the war, symbolizing the remembrance of the struggle for independence [Data: Bangladesh Forces and Liberation War (1); Entities (14); Relationships (1)].
#
# Overall, the data provides a comprehensive overview of the strategic military operations, formation of key military units, and the leadership that contributed to the success of the Bangladesh Liberation War.
# CPU times: total: 0 ns
# Wall time: 35.6 s
# {'reports': [{'id': '1',
#    'title': 'Bangladesh Forces and Liberation War',
#    'content': "# Bangladesh Forces and Liberation War\n\nThe community is centered around the Bangladesh Forces, which played a pivotal role in the Bangladesh Liberation War. Key entities include the Bangladesh Air Force, Bangladesh Navy, and various brigades such as Z Force, K Force, and S Force. The community's activities were supported by operations in Indian Territory and memorialized at Shikha Anirban.\n\n## Role of Bangladesh Forces in the Liberation War\n\nThe Bangladesh Forces were a crucial component in the Bangladesh Liberation War, consisting of guerrilla fighters and military personnel who defected from the Pakistan Army, Navy, and Air Force. These forces were instrumental in the fight for Bangladesh's independence, engaging in various military operations against the Pakistan Army [Data: Entities (2); Relationships (0)].\n\n## Formation and significance of the Bangladesh Air Force\n\nThe Bangladesh Air Force was officially formed on 28 September 1971, with personnel of Bengali origin from the Pakistan Air Force. This formation was a significant development in the military capabilities of the Bangladesh Forces, providing air support during the liberation efforts. The Air Force began its operations from an airfield in Dimapur, highlighting its strategic importance [Data: Entities (7); Claims (5); Relationships (7, 20)].\n\n## Strategic operations in Indian Territory\n\nThe Bangladesh Forces organized regular units across the border in Indian Territory, which played a strategic role in their operations during the war. This cross-border collaboration was crucial for logistical support and military planning, enhancing the effectiveness of the Bangladesh Forces [Data: Entities (15); Relationships (8)].\n\n## Commemoration at Shikha Anirban\n\nShikha Anirban, meaning Eternal Flame, is a memorial located at Dhaka Cantonment. It serves as a site for laying floral wreaths to honor the sacrifices made during the Bangladesh Liberation War. This memorial symbolizes the enduring legacy and remembrance of the struggle for independence [Data: Entities (14); Relationships (1)].\n\n## Formation of the Bangladesh Navy\n\nThe Bangladesh Navy was formed as part of the Bangladesh Forces, contributing to the maritime defense and operations during the liberation war. This formation was a critical step in establishing a comprehensive military structure for the newly emerging nation [Data: Relationships (6)].",
#    'index_name': 'test1',
#    'index_id': '1'},
#   {'id': '4',
#    'title': 'S Force and Bangladesh Liberation War',
#    'content': "# S Force and Bangladesh Liberation War\n\nThe community is centered around S Force, a brigade of the Bangladesh Forces, which played a significant role during the Bangladesh Liberation War. Key entities include Major K M Shafiullah, the commander of S Force, and Hezamara, the location where S Force was formed. The brigade was composed of battalions from the East Bengal Regiment, highlighting its strategic importance in the war effort.\n\n## S Force as a pivotal military unit\n\nS Force was a brigade within the Bangladesh Forces, underscoring its importance in the military operations during the Bangladesh Liberation War. The formation of S Force with battalions from the East Bengal Regiment indicates its strategic role in the conflict. This brigade's operations and contributions were vital in the context of the war, making it a key entity in the historical narrative of Bangladesh's fight for independence [Data: Entities (5); Relationships (5, 16)].\n\n## Major K M Shafiullah's leadership\n\nMajor K M Shafiullah served as the commander of S Force, highlighting his leadership role during the Bangladesh Liberation War. His command was crucial in directing the operations of S Force, which was a significant component of the Bangladesh Forces. The leadership of Major Shafiullah is a noteworthy aspect of the community, reflecting the human element behind the military strategies and actions taken during the war [Data: Entities (10); Relationships (15)].\n\n## Formation of S Force at Hezamara\n\nHezamara is identified as the location where S Force was formed, marking it as a significant geographical point in the history of the Bangladesh Liberation War. The formation of such a pivotal brigade at this location underscores its strategic importance. Understanding the role of Hezamara provides insights into the logistical and strategic planning that went into the war efforts [Data: Entities (18); Relationships (17)].\n\n## Integration of East Bengal Regiment battalions\n\nS Force was formed with battalions from the East Bengal Regiment, indicating a strategic integration of existing military resources to bolster the Bangladesh Forces. This integration reflects the tactical decisions made to enhance the effectiveness of the military operations during the liberation war. The East Bengal Regiment's involvement is a testament to the collaborative efforts within the Bangladesh Forces [Data: Relationships (16)].",
#    'index_name': 'test1',
#    'index_id': '4'},
#   {'id': '1',
#    'title': 'Bangladesh Forces and Liberation War',
#    'content': "# Bangladesh Forces and Liberation War\n\nThe community is centered around the Bangladesh Forces, which played a pivotal role in the Bangladesh Liberation War. Key entities include the Bangladesh Air Force, Bangladesh Navy, and various brigades such as Z Force, K Force, and S Force. The community's activities were supported by operations in Indian Territory and memorialized at Shikha Anirban.\n\n## Role of Bangladesh Forces in the Liberation War\n\nThe Bangladesh Forces were a crucial component in the Bangladesh Liberation War, consisting of guerrilla fighters and military personnel who defected from the Pakistan Army, Navy, and Air Force. These forces were instrumental in the fight for Bangladesh's independence, engaging in various military operations against the Pakistan Army [Data: Entities (2); Relationships (0)].\n\n## Formation and significance of the Bangladesh Air Force\n\nThe Bangladesh Air Force was officially formed on 28 September 1971, with personnel of Bengali origin from the Pakistan Air Force. This formation was a significant development in the military capabilities of the Bangladesh Forces, providing air support during the liberation efforts. The Air Force began its operations from an airfield in Dimapur, highlighting its strategic importance [Data: Entities (7); Claims (5); Relationships (7, 20)].\n\n## Strategic operations in Indian Territory\n\nThe Bangladesh Forces organized regular units across the border in Indian Territory, which played a strategic role in their operations during the war. This cross-border collaboration was crucial for logistical support and military planning, enhancing the effectiveness of the Bangladesh Forces [Data: Entities (15); Relationships (8)].\n\n## Commemoration at Shikha Anirban\n\nShikha Anirban, meaning Eternal Flame, is a memorial located at Dhaka Cantonment. It serves as a site for laying floral wreaths to honor the sacrifices made during the Bangladesh Liberation War. This memorial symbolizes the enduring legacy and remembrance of the struggle for independence [Data: Entities (14); Relationships (1)].\n\n## Formation of the Bangladesh Navy\n\nThe Bangladesh Navy was formed as part of the Bangladesh Forces, contributing to the maritime defense and operations during the liberation war. This formation was a critical step in establishing a comprehensive military structure for the newly emerging nation [Data: Relationships (6)].",
#    'index_name': 'test1',
#    'index_id': '1'},
#   {'id': '4',
#    'title': 'S Force and Bangladesh Liberation War',
#    'content': "# S Force and Bangladesh Liberation War\n\nThe community is centered around S Force, a brigade of the Bangladesh Forces, which played a significant role during the Bangladesh Liberation War. Key entities include Major K M Shafiullah, the commander of S Force, and Hezamara, the location where S Force was formed. The brigade was composed of battalions from the East Bengal Regiment, highlighting its strategic importance in the war effort.\n\n## S Force as a pivotal military unit\n\nS Force was a brigade within the Bangladesh Forces, underscoring its importance in the military operations during the Bangladesh Liberation War. The formation of S Force with battalions from the East Bengal Regiment indicates its strategic role in the conflict. This brigade's operations and contributions were vital in the context of the war, making it a key entity in the historical narrative of Bangladesh's fight for independence [Data: Entities (5); Relationships (5, 16)].\n\n## Major K M Shafiullah's leadership\n\nMajor K M Shafiullah served as the commander of S Force, highlighting his leadership role during the Bangladesh Liberation War. His command was crucial in directing the operations of S Force, which was a significant component of the Bangladesh Forces. The leadership of Major Shafiullah is a noteworthy aspect of the community, reflecting the human element behind the military strategies and actions taken during the war [Data: Entities (10); Relationships (15)].\n\n## Formation of S Force at Hezamara\n\nHezamara is identified as the location where S Force was formed, marking it as a significant geographical point in the history of the Bangladesh Liberation War. The formation of such a pivotal brigade at this location underscores its strategic importance. Understanding the role of Hezamara provides insights into the logistical and strategic planning that went into the war efforts [Data: Entities (18); Relationships (17)].\n\n## Integration of East Bengal Regiment battalions\n\nS Force was formed with battalions from the East Bengal Regiment, indicating a strategic integration of existing military resources to bolster the Bangladesh Forces. This integration reflects the tactical decisions made to enhance the effectiveness of the military operations during the liberation war. The East Bengal Regiment's involvement is a testament to the collaborative efforts within the Bangladesh Forces [Data: Relationships (16)].",
#    'index_name': 'test1',
#    'index_id': '4'}],
#  'entities': [{'id': '15',
#    'entity': 'INDIAN TERRITORY',
#    'description': 'Indian Territory refers to the areas across the border where Bangladesh Forces organized regular units during the war',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 15},
#   {'id': '10',
#    'entity': 'K M SHAFIULLAH',
#    'description': 'Major K M Shafiullah was the commander of S Force during the Bangladesh Liberation War',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 10},
#   {'id': '13',
#    'entity': 'DIMAPUR',
#    'description': 'Dimapur is the location of an abandoned airfield from which the Bangladesh Air Force started their operations',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 13},
#   {'id': '17',
#    'entity': 'AGARTALA',
#    'description': 'Agartala is a location where K Force was formed during the Bangladesh Liberation War',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 17},
#   {'id': '9',
#    'entity': 'KHALED MOSHARRAF',
#    'description': 'Lieutenant Colonel Khaled Mosharraf was the commander of K Force during the Bangladesh Liberation War',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 9},
#   {'id': '18',
#    'entity': 'HEZAMARA',
#    'description': 'Hezamara is a location where S Force was formed during the Bangladesh Liberation War',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 18},
#   {'id': '1',
#    'entity': 'DHAKA',
#    'description': 'Dhaka is the capital city of Bangladesh where the initial crackdown by the Pakistan Army occurred on 25 March 1971',
#    'number of relationships': '0',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 1},
#   {'id': '12',
#    'entity': 'MONGLA',
#    'description': 'Mongla is a port city in Bangladesh where naval operations by the Bangladesh Navy made it highly lethal for occupation forces',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 12},
#   {'id': '11',
#    'entity': 'CHITTAGONG',
#    'description': 'Chittagong is a port city in Bangladesh where naval operations by the Bangladesh Navy made it highly lethal for occupation forces',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 11},
#   {'id': '16',
#    'entity': 'EAST BENGAL REGIMENT',
#    'description': 'The East Bengal Regiment was a military unit whose battalions formed the core of the Z, K, and S Forces during the Bangladesh Liberation War',
#    'number of relationships': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 16},
#   {'id': '20',
#    'entity': 'PAKISTAN ARMY',
#    'description': '',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 20},
#   {'id': '8',
#    'entity': 'ZIAUR RAHMAN',
#    'description': 'Lieutenant Colonel Ziaur Rahman was the commander of Z Force during the Bangladesh Liberation War',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 8},
#   {'id': '5',
#    'entity': 'S FORCE',
#    'description': 'S Force was a brigade of the Bangladesh Forces commanded by Major K M Shafiullah, formed with battalions of the East Bengal Regiment',
#    'number of relationships': '4',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 5},
#   {'id': '4',
#    'entity': 'K FORCE',
#    'description': 'K Force was a brigade of the Bangladesh Forces commanded by Lieutenant Colonel Khaled Mosharraf, formed with battalions of the East Bengal Regiment',
#    'number of relationships': '4',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 4},
#   {'id': '2',
#    'entity': 'BANGLADESH FORCES',
#    'description': "The Bangladesh Forces were organized groups of guerrilla fighters and military personnel who deserted the Pakistan Army, Navy, and Air Force to fight for Bangladesh's independence",
#    'number of relationships': '7',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 2},
#   {'id': '3',
#    'entity': 'Z FORCE',
#    'description': 'Z Force was a brigade of the Bangladesh Forces commanded by Lieutenant Colonel Ziaur Rahman, formed with battalions of the East Bengal Regiment',
#    'number of relationships': '4',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 3},
#   {'id': '6',
#    'entity': 'BANGLADESH NAVY',
#    'description': 'The Bangladesh Navy was formed by Bengali sailors and officers who left the Pakistan Navy, initially with two ships and 45 personnel',
#    'number of relationships': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 6},
#   {'id': '0',
#    'entity': 'BANGLADESH LIBERATION WAR',
#    'description': 'The Bangladesh Liberation War was a conflict that began on 25 March 1971 as a resistance movement against the Pakistan Army, leading to the independence of Bangladesh',
#    'number of relationships': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 0},
#   {'id': '14',
#    'entity': 'SHIKHA ANIRBAN',
#    'description': 'Shikha Anirban, meaning Eternal Flame, is a memorial at Dhaka Cantonment where floral wreaths are laid to commemorate the Bangladesh Liberation War',
#    'number of relationships': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 14},
#   {'id': '7',
#    'entity': 'BANGLADESH AIR FORCE',
#    'description': 'The Bangladesh Air Force was officially formed on 28 September 1971 with officers and airmen of Bengali origin from the Pakistan Air Force',
#    'number of relationships': '2',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 7}],
#  'relationships': [{'id': '3',
#    'source': 'BANGLADESH FORCES',
#    'target': 'Z FORCE',
#    'description': 'Z Force was a brigade within the Bangladesh Forces',
#    'weight': '8.0',
#    'rank': '11',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 3},
#   {'id': '4',
#    'source': 'BANGLADESH FORCES',
#    'target': 'K FORCE',
#    'description': 'K Force was a brigade within the Bangladesh Forces',
#    'weight': '8.0',
#    'rank': '11',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 4},
#   {'id': '5',
#    'source': 'BANGLADESH FORCES',
#    'target': 'S FORCE',
#    'description': 'S Force was a brigade within the Bangladesh Forces',
#    'weight': '8.0',
#    'rank': '11',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 5},
#   {'id': '0',
#    'source': 'BANGLADESH LIBERATION WAR',
#    'target': 'BANGLADESH FORCES',
#    'description': 'The Bangladesh Forces were key participants in the Bangladesh Liberation War, fighting against the Pakistan Army',
#    'weight': '9.0',
#    'rank': '10',
#    'links': '2',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 0},
#   {'id': '6',
#    'source': 'BANGLADESH FORCES',
#    'target': 'BANGLADESH NAVY',
#    'description': 'The Bangladesh Navy was formed as part of the Bangladesh Forces',
#    'weight': '7.0',
#    'rank': '10',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 6},
#   {'id': '7',
#    'source': 'BANGLADESH FORCES',
#    'target': 'BANGLADESH AIR FORCE',
#    'description': 'The Bangladesh Air Force was formed as part of the Bangladesh Forces',
#    'weight': '7.0',
#    'rank': '9',
#    'links': '2',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 7},
#   {'id': '8',
#    'source': 'BANGLADESH FORCES',
#    'target': 'INDIAN TERRITORY',
#    'description': 'Bangladesh Forces organized regular units across the border in Indian Territory',
#    'weight': '6.0',
#    'rank': '8',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 8},
#   {'id': '10',
#    'source': 'Z FORCE',
#    'target': 'EAST BENGAL REGIMENT',
#    'description': 'Z Force was formed with battalions from the East Bengal Regiment',
#    'weight': '8.0',
#    'rank': '7',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 10},
#   {'id': '13',
#    'source': 'K FORCE',
#    'target': 'EAST BENGAL REGIMENT',
#    'description': 'K Force was formed with battalions from the East Bengal Regiment',
#    'weight': '8.0',
#    'rank': '7',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 13},
#   {'id': '16',
#    'source': 'S FORCE',
#    'target': 'EAST BENGAL REGIMENT',
#    'description': 'S Force was formed with battalions from the East Bengal Regiment',
#    'weight': '8.0',
#    'rank': '7',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 16},
#   {'id': '9',
#    'source': 'Z FORCE',
#    'target': 'ZIAUR RAHMAN',
#    'description': 'Ziaur Rahman was the commander of Z Force',
#    'weight': '9.0',
#    'rank': '5',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 9},
#   {'id': '12',
#    'source': 'K FORCE',
#    'target': 'KHALED MOSHARRAF',
#    'description': 'Khaled Mosharraf was the commander of K Force',
#    'weight': '9.0',
#    'rank': '5',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 12},
#   {'id': '14',
#    'source': 'K FORCE',
#    'target': 'AGARTALA',
#    'description': 'K Force was formed at Agartala',
#    'weight': '7.0',
#    'rank': '5',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 14},
#   {'id': '15',
#    'source': 'S FORCE',
#    'target': 'K M SHAFIULLAH',
#    'description': 'K M Shafiullah was the commander of S Force',
#    'weight': '9.0',
#    'rank': '5',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 15},
#   {'id': '17',
#    'source': 'S FORCE',
#    'target': 'HEZAMARA',
#    'description': 'S Force was formed at Hezamara',
#    'weight': '7.0',
#    'rank': '5',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 17},
#   {'id': '1',
#    'source': 'BANGLADESH LIBERATION WAR',
#    'target': 'SHIKHA ANIRBAN',
#    'description': 'Shikha Anirban is a memorial commemorating the Bangladesh Liberation War',
#    'weight': '1.0',
#    'rank': '4',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 1},
#   {'id': '2',
#    'source': 'BANGLADESH LIBERATION WAR',
#    'target': 'PAKISTAN ARMY',
#    'description': "The Pakistan Army's crackdown on Dhaka initiated the Bangladesh Liberation War",
#    'weight': '9.0',
#    'rank': '4',
#    'links': '2',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 2},
#   {'id': '18',
#    'source': 'BANGLADESH NAVY',
#    'target': 'CHITTAGONG',
#    'description': 'The Bangladesh Navy conducted operations in Chittagong',
#    'weight': '7.0',
#    'rank': '4',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 18},
#   {'id': '19',
#    'source': 'BANGLADESH NAVY',
#    'target': 'MONGLA',
#    'description': 'The Bangladesh Navy conducted operations in Mongla',
#    'weight': '7.0',
#    'rank': '4',
#    'links': '3',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 19},
#   {'id': '20',
#    'source': 'BANGLADESH AIR FORCE',
#    'target': 'DIMAPUR',
#    'description': 'The Bangladesh Air Force started operations from an airfield in Dimapur',
#    'weight': '7.0',
#    'rank': '3',
#    'links': '2',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 20},
#   {'id': '11',
#    'source': 'Z FORCE',
#    'target': 'MYMENSINGH',
#    'description': 'Z Force was raised opposite to Mymensingh',
#    'weight': '1.0',
#    'rank': '5',
#    'links': '1',
#    'in_context': True,
#    'index_name': 'test1',
#    'index_id': 11}],
#  'claims': [],
#  'sources': [{'id': '0',
#    'text': 'History\nBangladesh Liberation War initially commenced in the form of resistance movement as the Pakistan Army cracked down on 25 March 1971 primarily at Dhaka and subsequently extending it to the entire of Bangladesh. Gradually, the Bangladesh Forces organised small groups of guerrilla fighters who followed \'hit and run\'[5] tactics. As a third stage in the war, the Bengali military personnel who were members of Pakistan Army, Navy and Air Force deserted their respective units to join Bangladesh Forces and organised them into regular units across the border of Indian territory primarily as Land Force. A small group of naval commandos also opened the naval wing and a few pilots and airmen formed the air wing.[citation needed]\n\nBangladesh Army After a prolonged guerrilla warfare was launched by Bangladesh Forces, which continued for a number of months. A further restructuring was undertaken, and the Bangladesh Forces were organised into three brigade size combat groups.\n\n\'Z\' Force,:[3] Lieutenant Colonel Ziaur Rahman was the commander of this force. The brigade was formed with the 1st, 3rd and 8th Battalion of East Bengal Regiment on 7 July 1971. The Z Force was raised at the foothills of Tura hill, opposite to Mymensingh.[3]\n\'K\' Force: Lieutenant Colonel (later Brigadier) Khaled Mosharraf was the commander of this force. The brigade was formed at Agartala,[3] with the 4th, 9th and 10th Battalion of East Bengal Regiment on the month of September 1971.\n\'S\' Force: Major K M Shafiullah was the commander of this force. The Brigade was formed at Hezamara,[3] with the 2nd and 11th Battalion of East Bengal Regiment on the month of October 1971.[6]\nBangladesh Navy Many of the Bengali sailors and officers in the Pakistan Navy decamped, to form an emerging Bangladesh Navy. Initially, there were two ships BNS Padma (1973) and PALASH and 45 navy personnel. They prevented the supply of arms, ammunitions and rations for the occupation forces. This operation from the Naval Commandos made Ports in Chittagong and Mongla highly lethal for the occupation forces.[3]\n\nBangladesh Air Force The official date of formation of the Bangladesh Air Force (BAF) has been established as 28 September 1971 and it was launched formally by the Government on 8 October 1971. BAF was formed with all officers and airmen of Bengali origin serving in the Pakistan Air Force prior to the war. Out of 11 BDF Sectors, the most tactically significant sector, the Central Sector – Sector 11, was in command of a BAF officer including Sector 6. The BAF started their operation from an abandoned airfield at Dimapur.[3]\n\nPrograms\nThe day starts with laying of floral wreath at \'Shikha Anirban\' (Eternal Flame) at Dhaka Cantonment by the President, the Prime Minister and the Service Chiefs. In the afternoon a reception at Senakunja, Dhaka Cantonment is held where the Prime Minister, ministers, the leader of opposition and other high civil and military officials attend.[7][8] In other Cantonments, naval and air bases similar receptions are held. A special TV programme "Anirban" is broadcast on different TV channels the previous evening and special newspaper supplements are also published with national dailies. Receptions are also held by the Prime Minister and Service Chiefs for recipients of the gallantry award Freedom fighter. Improved meals for family members are served in all military stations. Armed Forces Division also brings out a special publication with articles related to the War of Independence and armed forces.[9][10]'}]}
